# %% [markdown]
# ## Dados da Camada Bronze

# %%
import pandas as pd
import numpy as np

# %%
# buscando os dados da camada Bronze

data_bronze = pd.read_csv("Bronze/bronze_alunos_5000.csv", sep=",", encoding="utf-8")

# %%
data_bronze.head()
# Out:
#    NU_ANO_AVALIACAO  CO_UF SG_UF  ID_ALUNO  TP_SERIE  ID_ESCOLA  \
# 0              2024     31    MG  31136862         2   60021275
# 1              2024     24    RN  24004269         2   60010114
# 2              2024     25    PB  25017200         2   60010962
# 3              2024     42    SC  42051866         2   60034809
# 4              2024     23    CE  23038517         2   60009206
#
#    TP_DEPENDENCIA  CO_MUNICIPIO   NO_MUNICIPIO  IN_PRESENCA_LP  \
# 0               3       3119955  Córrego Fundo               1
# 1               3       2408102          Natal               1
# 2               3       2515302           Sapé               1
# 3               3       4209102      Joinville               1
# 4               3       2304400      Fortaleza               1
#
#    IN_PREENCHIMENTO_LP  CO_CADERNO_LP  VL_PESO_ALUNO_LP  VL_PROFICIENCIA_LP  \
# 0                    1              5              1.07              801.24
# ...

# %%
data_bronze.describe()
# Out:
#        NU_ANO_AVALIACAO       CO_UF      ID_ALUNO  TP_SERIE     ID_ESCOLA  \
# count            5000.0  5000.00000  5.000000e+03    5000.0  5.000000e+03
# mean             2024.0    32.47960  3.257378e+07       2.0  6.002262e+07
# std                 0.0    10.10776  1.011837e+07       0.0  1.221237e+04
# min              2024.0    11.00000  1.100047e+07       2.0  6.000000e+07
# 25%              2024.0    26.00000  2.605632e+07       2.0  6.001274e+07
# 50%              2024.0    33.00000  3.306374e+07       2.0  6.002433e+07
# 75%              2024.0    41.00000  4.101898e+07       2.0  6.003219e+07
# max              2024.0    53.00000  5.302710e+07       2.0  6.004249e+07
#
#        TP_DEPENDENCIA  CO_MUNICIPIO  IN_PRESENCA_LP  IN_PREENCHIMENTO_LP  \
# count     5000.000000  5.000000e+03     5000.000000          5000.000000
# mean         2.866200  3.264229e+06        0.874400             0.874200
# std          0.340471  1.013077e+06        0.331431             0.331657
# ...

# %%
data_bronze.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   NU_ANO_AVALIACAO     5000 non-null   int64
#  1   CO_UF                5000 non-null   int64
#  2   SG_UF                5000 non-null   str
#  3   ID_ALUNO             5000 non-null   int64
#  4   TP_SERIE             5000 non-null   int64
#  5   ID_ESCOLA            5000 non-null   int64
#  6   TP_DEPENDENCIA       5000 non-null   int64
#  7   CO_MUNICIPIO         5000 non-null   int64
#  8   NO_MUNICIPIO         5000 non-null   str
#  9   IN_PRESENCA_LP       5000 non-null   int64
#  10  IN_PREENCHIMENTO_LP  5000 non-null   int64
#  11  CO_CADERNO_LP        5000 non-null   int64
#  12  VL_PESO_ALUNO_LP     4371 non-null   float64
#  13  VL_PROFICIENCIA_LP   4371 non-null   float64
#  14  IN_ALFABETIZADO      5000 non-null   int64
# dtypes: float64(2), int64(11), str(2)
# ...

# %%
data_bronze.shape
# Out:
# (5000, 15)

# %%
# coletando os dados de manifesto_fontes
manifesto_fontes = pd.read_csv("Bronze/_manifesto_fontes.csv", sep=",", encoding="utf-8")

# %%
manifesto_fontes.head()
# Out:
#         fonte                                                url  \
# 0  brasil_ufs  https://download.inep.gov.br/alfabetiza_brasil...
# 1  municipios  https://download.inep.gov.br/alfabetiza_brasil...
# 2  microdados  https://download.inep.gov.br/dados_abertos/mic...
#
#                                     arquivo_original  linhas_origem  \
# 0  G:\Meu Drive\FIAP\AI_Scientist\Fase3\techallen...             46
# 1  G:\Meu Drive\FIAP\AI_Scientist\Fase3\techallen...           5377
# 2  G:\Meu Drive\FIAP\AI_Scientist\Fase3\techallen...        2120560
#
#    linhas_bronze                                    arquivo_tabular
# 0             46                                                NaN
# 1           5000                                                NaN
# 2           5000  G:\Meu Drive\FIAP\AI_Scientist\Fase3\techallen...

# %%
manifesto_fontes.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fonte             3 non-null      str
#  1   url               3 non-null      str
#  2   arquivo_original  3 non-null      str
#  3   linhas_origem     3 non-null      int64
#  4   linhas_bronze     3 non-null      int64
#  5   arquivo_tabular   1 non-null      str
# dtypes: int64(2), str(4)
# memory usage: 276.0 bytes

# %%
# dados do bronze_brasil_ufs
bronze_brasil_ufs = pd.read_csv("Bronze/bronze_brasil_ufs.csv", sep=",", encoding="utf-8")
bronze_brasil_ufs.head()
# Out:
#                       _aba_origem ANO DA AVALIAÇÃO CÓDIGO UF  SIGLA UF  \
# 0  Divulgação Alfabet UF e Brasil              ANO     CD_UF  SIGLA_UF
# 1  Divulgação Alfabet UF e Brasil             2024       NaN       NaN
# 2  Divulgação Alfabet UF e Brasil             2024        12        AC
# 3  Divulgação Alfabet UF e Brasil             2024        27        AL
# 4  Divulgação Alfabet UF e Brasil             2024        13        AM
#
#     NOME UF     REDE  \
# 0   NOME_UF     REDE
# 1    Brasil  PÚBLICA
# 2      Acre  PÚBLICA
# 3   Alagoas  PÚBLICA
# 4  Amazonas  PÚBLICA
#
#   PERCENTUAL DE ALUNOS ALFABETIZADOS Sistemas estaduais de avaliação 2023  \
# 0                         PC_ALUNO_ALFABETIZADO_2023
# 1                                               55.9
# 2                                                 -
# 3                                              43.88
# 4                                               52.2
#
# ...

# %%
bronze_brasil_ufs.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 18 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   _aba_origem                                                              46 non-null     str
#  1   ANO DA AVALIAÇÃO                                                         29 non-null     str
#  2   CÓDIGO UF                                                                28 non-null     str
#  3   SIGLA UF                                                                 28 non-null     str
#  4   NOME UF                                                                  29 non-null     str
#  5   REDE                                                                     29 non-null     str
# ...

# %%
#Bronze municipios
bronze_brasil_municipios = pd.read_csv("Bronze/bronze_municipios.csv", sep=",", encoding="utf-8")
bronze_brasil_municipios.head()
# Out:
#                     _aba_origem ANO DA AVALIAÇÃO CÓDIGO UF SIGLA UF  \
# 0  Divulgação Alfabet Municipio             2024        29       BA
# 1  Divulgação Alfabet Municipio             2024        42       SC
# 2  Divulgação Alfabet Municipio             2024        17       TO
# 3  Divulgação Alfabet Municipio             2024        31       MG
# 4  Divulgação Alfabet Municipio             2024        43       RS
#
#   CÓDIGO MUNICÍPIO        NOME DO MUNICÍPIO       REDE  \
# 0          2932705                  Uruçuca  MUNICIPAL
# 1          4209854           Lindóia do Sul  MUNICIPAL
# 2          1720200  São Miguel do Tocantins  MUNICIPAL
# 3          3105202                 Bandeira  MUNICIPAL
# 4          4307450         Esperança do Sul  MUNICIPAL
#
#   PERCENTUAL DE ALUNOS ALFABETIZADOS  - 2023 (1)  \
# 0                                             30
# 1                                           87.4
# 2                                             27
# ...

# %%
bronze_brasil_municipios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   _aba_origem                                     5000 non-null   str
#  1   ANO DA AVALIAÇÃO                                4980 non-null   str
#  2   CÓDIGO UF                                       4980 non-null   str
#  3   SIGLA UF                                        4980 non-null   str
#  4   CÓDIGO MUNICÍPIO                                4980 non-null   str
#  5   NOME DO MUNICÍPIO                               4980 non-null   str
#  6   REDE                                            4980 non-null   str
#  7   PERCENTUAL DE ALUNOS ALFABETIZADOS  - 2023 (1)  4868 non-null   str
#  8   PERCENTUAL DE ALUNOS ALFABETIZADOS  - 2024 (1)  4980 non-null   str
# ...

# %% [markdown]
# ## Dados Camada Silver

# %%
#Conhecendo os dados da camada silver (_relatorio_qualidade, silver_alunos, silver_municipios, silver_ufs)

silver_relatorio_qualidade = pd.read_csv("Silver/_relatorio_qualidade.csv", sep=",", encoding="utf-8")
silver_relatorio_qualidade.head(10)
# Out:
#    tabela                 teste            coluna  resultado status
# 0  alunos  duplicatas_removidas               NaN          0     OK
# 1  alunos         valores_nulos     ano_avaliacao          0   INFO
# 2  alunos         valores_nulos         codigo_uf          0   INFO
# 3  alunos         valores_nulos          sigla_uf          0   INFO
# 4  alunos         valores_nulos          id_aluno          0   INFO
# 5  alunos         valores_nulos        tipo_serie          0   INFO
# 6  alunos         valores_nulos         id_escola          0   INFO
# 7  alunos         valores_nulos  tipo_dependencia          0   INFO
# 8  alunos         valores_nulos  codigo_municipio          0   INFO
# 9  alunos         valores_nulos    nome_municipio          0   INFO

# %%
silver_relatorio_qualidade.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tabela     75 non-null     str
#  1   teste      75 non-null     str
#  2   coluna     72 non-null     str
#  3   resultado  75 non-null     int64
#  4   status     75 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 3.1 KB

# %%
#silver alunos

silver_alunos = pd.read_csv("Silver/silver_alunos.csv", sep=",", encoding="utf-8")
silver_alunos.head()
# Out:
#    ano_avaliacao  codigo_uf sigla_uf  id_aluno  tipo_serie  id_escola  \
# 0           2024         31       MG  31136862           2   60021275
# 1           2024         24       RN  24004269           2   60010114
# 2           2024         25       PB  25017200           2   60010962
# 3           2024         42       SC  42051866           2   60034809
# 4           2024         23       CE  23038517           2   60009206
#
#    tipo_dependencia  codigo_municipio nome_municipio  presenca_lp  \
# 0                 3           3119955  Córrego Fundo            1
# 1                 3           2408102          Natal            1
# 2                 3           2515302           Sapé            1
# 3                 3           4209102      Joinville            1
# 4                 3           2304400      Fortaleza            1
#
#    preenchimento_lp  codigo_caderno_lp  peso_aluno_lp  proficiencia_lp  \
# 0                 1                  5           1.07           801.24
# ...

# %%
silver_alunos.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ano_avaliacao      5000 non-null   int64
#  1   codigo_uf          5000 non-null   int64
#  2   sigla_uf           5000 non-null   str
#  3   id_aluno           5000 non-null   int64
#  4   tipo_serie         5000 non-null   int64
#  5   id_escola          5000 non-null   int64
#  6   tipo_dependencia   5000 non-null   int64
#  7   codigo_municipio   5000 non-null   int64
#  8   nome_municipio     5000 non-null   str
#  9   presenca_lp        5000 non-null   int64
#  10  preenchimento_lp   5000 non-null   int64
#  11  codigo_caderno_lp  5000 non-null   int64
#  12  peso_aluno_lp      4371 non-null   float64
#  13  proficiencia_lp    4371 non-null   float64
#  14  alfabetizado       5000 non-null   int64
# dtypes: float64(2), int64(11), str(2)
# memory usage: 586.1 KB

# %%
#silver municipios

silver_municipios = pd.read_csv("Silver/silver_municipios.csv", sep=",", encoding="utf-8")
silver_municipios.head()
# Out:
#                      aba_origem  ano_avaliacao  codigo_uf sigla_uf  \
# 0  Divulgação Alfabet Municipio         2024.0       29.0       BA
# 1  Divulgação Alfabet Municipio         2024.0       42.0       SC
# 2  Divulgação Alfabet Municipio         2024.0       17.0       TO
# 3  Divulgação Alfabet Municipio         2024.0       31.0       MG
# 4  Divulgação Alfabet Municipio         2024.0       43.0       RS
#
#    codigo_municipio           nome_municipio       rede  \
# 0         2932705.0                  Uruçuca  MUNICIPAL
# 1         4209854.0           Lindóia do Sul  MUNICIPAL
# 2         1720200.0  São Miguel do Tocantins  MUNICIPAL
# 3         3105202.0                 Bandeira  MUNICIPAL
# 4         4307450.0         Esperança do Sul  MUNICIPAL
#
#    pct_alfabetizados_2023  pct_alfabetizados_2024  meta_2024  meta_2025  \
# 0                    30.0                   26.42      37.10      44.80
# 1                    87.4                   84.61      80.00      80.00
# ...

# %%
silver_municipios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   aba_origem              4981 non-null   str
#  1   ano_avaliacao           4979 non-null   float64
#  2   codigo_uf               4980 non-null   float64
#  3   sigla_uf                4980 non-null   str
#  4   codigo_municipio        4980 non-null   float64
#  5   nome_municipio          4980 non-null   str
#  6   rede                    4980 non-null   str
#  7   pct_alfabetizados_2023  4867 non-null   float64
#  8   pct_alfabetizados_2024  4979 non-null   float64
#  9   meta_2024               4867 non-null   float64
#  10  meta_2025               4979 non-null   float64
#  11  meta_2026               4979 non-null   float64
#  12  meta_2027               4979 non-null   float64
#  13  meta_2028               4979 non-null   float64
# ...

# %%
#silver ufs
silver_ufs = pd.read_csv("Silver/silver_ufs.csv", sep=",", encoding="utf-8")
silver_ufs.head()
# Out:
#                        aba_origem  ano_avaliacao  codigo_uf  sigla_uf  \
# 0  Divulgação Alfabet UF e Brasil            NaN        0.0  SIGLA_UF
# 1  Divulgação Alfabet UF e Brasil         2024.0        NaN       NaN
# 2  Divulgação Alfabet UF e Brasil         2024.0       12.0        AC
# 3  Divulgação Alfabet UF e Brasil         2024.0       27.0        AL
# 4  Divulgação Alfabet UF e Brasil         2024.0       13.0        AM
#
#     nome_uf     rede  pct_alfabetizados_2023  pct_alfabetizados_2024  \
# 0   NOME_UF     REDE                     NaN                     NaN
# 1    Brasil  PÚBLICA                   55.90               59.197271
# 2      Acre  PÚBLICA                     NaN               51.380000
# 3   Alagoas  PÚBLICA                   43.88               48.630000
# 4  Amazonas  PÚBLICA                   52.20               49.170000
#
#    meta_2024  meta_2025  meta_2026  meta_2027  meta_2028  meta_2029  \
# ...

# %%
silver_ufs.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   aba_origem              30 non-null     str
#  1   ano_avaliacao           28 non-null     float64
#  2   codigo_uf               28 non-null     float64
#  3   sigla_uf                28 non-null     str
#  4   nome_uf                 29 non-null     str
#  5   rede                    29 non-null     str
#  6   pct_alfabetizados_2023  25 non-null     float64
#  7   pct_alfabetizados_2024  27 non-null     float64
#  8   meta_2024               24 non-null     float64
#  9   meta_2025               26 non-null     float64
#  10  meta_2026               26 non-null     float64
#  11  meta_2027               26 non-null     float64
#  12  meta_2028               26 non-null     float64
#  13  meta_2029               26 non-null     float64
# ...

# %% [markdown]
# ## Dados Camada Gold

# %%
## _resumo_gold
data_resumo_gold = pd.read_csv("Gold/_resumo_gold.csv", sep=",", encoding="utf-8")
data_resumo_gold.head()
# Out:
#                             metrica  \
# 0                   municipios_gold
# 1                       alunos_gold
# 2  corte_proficiencia_alfabetizacao
# 3      observacao_ranking_municipal
#
#                                                valor
# 0                                               4981
# 1                                               5000
# 2                                                743
# 3  O ranking municipal é calculado sobre a amostr...

# %%
data_resumo_gold.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   metrica  4 non-null      str
#  1   valor    4 non-null      str
# dtypes: str(2)
# memory usage: 196.0 bytes

# %%
# gold_amostra_alunos
data_gold_amostra_alunos = pd.read_csv("Gold/gold_amostra_alunos.csv", sep=",", encoding="utf-8")
data_gold_amostra_alunos.head()
# Out:
#    ano_avaliacao  codigo_uf sigla_uf  codigo_municipio nome_municipio  \
# 0           2024         31       MG           3119955  Córrego Fundo
# 1           2024         24       RN           2408102          Natal
# 2           2024         25       PB           2515302           Sapé
# 3           2024         42       SC           4209102      Joinville
# 4           2024         23       CE           2304400      Fortaleza
#
#    id_aluno  id_escola  tipo_serie  tipo_dependencia  presenca_lp  \
# 0  31136862   60021275           2                 3            1
# 1  24004269   60010114           2                 3            1
# 2  25017200   60010962           2                 3            1
# 3  42051866   60034809           2                 3            1
# 4  23038517   60009206           2                 3            1
#
#    preenchimento_lp  codigo_caderno_lp  peso_aluno_lp  proficiencia_lp  \
# 0                 1                  5           1.07           801.24
# ...

# %%
# gold_evolucao_temporal_municipios
data_gold_evolucao_temporal_municipios = pd.read_csv("Gold/gold_evolucao_temporal_municipal.csv", sep=",", encoding="utf-8")
data_gold_evolucao_temporal_municipios.head()
# Out:
#    codigo_uf sigla_uf  codigo_municipio         nome_municipio  \
# 0        0.0    SG_UF               0.0           NO_MUNICIPIO
# 1        0.0    SG_UF               0.0           NO_MUNICIPIO
# 2       11.0       RO         1100015.0  Alta Floresta D'Oeste
# 3       11.0       RO         1100015.0  Alta Floresta D'Oeste
# 4       11.0       RO         1100023.0              Ariquemes
#
#    pct_alfabetizados   ano
# 0                NaN  2023
# 1                NaN  2024
# 2              64.60  2023
# 3              67.79  2024
# 4              62.30  2023

# %%
data_gold_evolucao_temporal_municipios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9962 entries, 0 to 9961
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   codigo_uf          9960 non-null   float64
#  1   sigla_uf           9960 non-null   str
#  2   codigo_municipio   9960 non-null   float64
#  3   nome_municipio     9960 non-null   str
#  4   pct_alfabetizados  9846 non-null   float64
#  5   ano                9962 non-null   int64
# dtypes: float64(3), int64(1), str(2)
# memory usage: 467.1 KB

# %%
#data gold_indicadores_municipios
data_gold_indicadores_municipios = pd.read_csv("Gold/gold_indicadores_municipios.csv", sep=",", encoding="utf-8")
data_gold_indicadores_municipios.head()
# Out:
#    ano_avaliacao  codigo_uf sigla_uf  codigo_municipio  \
# 0         2024.0       29.0       BA         2932705.0
# 1         2024.0       42.0       SC         4209854.0
# 2         2024.0       17.0       TO         1720200.0
# 3         2024.0       31.0       MG         3105202.0
# 4         2024.0       43.0       RS         4307450.0
#
#             nome_municipio       rede  pct_alfabetizados_2023  \
# 0                  Uruçuca  MUNICIPAL                    30.0
# 1           Lindóia do Sul  MUNICIPAL                    87.4
# 2  São Miguel do Tocantins  MUNICIPAL                    27.0
# 3                 Bandeira  MUNICIPAL                    62.7
# 4         Esperança do Sul  MUNICIPAL                    97.2
#
#    pct_alfabetizados_2024  variacao_2023_2024_pp  meta_2024  ...  meta_2025  \
# 0                   26.42                  -3.58      37.10  ...      44.80
# 1                   84.61                  -2.79      80.00  ...      80.00
# ...

# %%
data_gold_indicadores_municipios.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4981 entries, 0 to 4980
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ano_avaliacao                4979 non-null   float64
#  1   codigo_uf                    4980 non-null   float64
#  2   sigla_uf                     4980 non-null   str
#  3   codigo_municipio             4980 non-null   float64
#  4   nome_municipio               4980 non-null   str
#  5   rede                         4980 non-null   str
#  6   pct_alfabetizados_2023       4867 non-null   float64
#  7   pct_alfabetizados_2024       4979 non-null   float64
#  8   variacao_2023_2024_pp        4867 non-null   float64
#  9   meta_2024                    4867 non-null   float64
#  10  gap_meta_2024_pp             4867 non-null   float64
#  11  atingiu_meta_2024            4867 non-null   float64
#  12  meta_2025                    4979 non-null   float64
# ...

# %%
# gold_indicadores_ufs
data_gold_indicadores_ufs = pd.read_csv("Gold/gold_indicadores_ufs.csv", sep=",", encoding="utf-8")
data_gold_indicadores_ufs.head()
# Out:
#    ano_avaliacao  codigo_uf  sigla_uf   nome_uf     rede  \
# 0            NaN        0.0  SIGLA_UF   NOME_UF     REDE
# 1         2024.0        NaN       NaN    Brasil  PÚBLICA
# 2         2024.0       12.0        AC      Acre  PÚBLICA
# 3         2024.0       27.0        AL   Alagoas  PÚBLICA
# 4         2024.0       13.0        AM  Amazonas  PÚBLICA
#
#    pct_alfabetizados_2023  pct_alfabetizados_2024  variacao_2023_2024_pp  \
# 0                     NaN                     NaN                    NaN
# 1                   55.90               59.197271               3.297271
# 2                     NaN               51.380000                    NaN
# 3                   43.88               48.630000               4.750000
# 4                   52.20               49.170000              -3.030000
#
#    meta_2024  gap_meta_2024_pp  atingiu_meta_2024  meta_2025  meta_2026  \
# 0        NaN               NaN                NaN        NaN        NaN
# ...

# %%
data_gold_indicadores_ufs.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ano_avaliacao           28 non-null     float64
#  1   codigo_uf               28 non-null     float64
#  2   sigla_uf                28 non-null     str
#  3   nome_uf                 29 non-null     str
#  4   rede                    29 non-null     str
#  5   pct_alfabetizados_2023  25 non-null     float64
#  6   pct_alfabetizados_2024  27 non-null     float64
#  7   variacao_2023_2024_pp   25 non-null     float64
#  8   meta_2024               24 non-null     float64
#  9   gap_meta_2024_pp        24 non-null     float64
#  10  atingiu_meta_2024       24 non-null     float64
#  11  meta_2025               26 non-null     float64
#  12  meta_2026               26 non-null     float64
#  13  meta_2027               26 non-null     float64
# ...

# %%
# gold_resumo_municipal_por_uf
data_gold_resumo_municipal_por_uf = pd.read_csv("Gold/gold_resumo_municipal_por_uf.csv", sep=",", encoding="utf-8")
data_gold_resumo_municipal_por_uf.head()
# Out:
#   sigla_uf  municipios_na_amostra  media_pct_alfabetizados_2023  \
# 0       AC                     21                           NaN
# 1       AL                     92                     45.865217
# 2       AM                     53                     48.095652
# 3       AP                     16                     42.418750
# 4       BA                    372                     37.565217
#
#    media_pct_alfabetizados_2024  media_variacao_2023_2024_pp  \
# 0                     43.547143                          NaN
# 1                     52.868804                     7.003587
# 2                     44.939434                    -1.982174
# 3                     49.449375                     7.030625
# 4                     36.634946                    -0.951712
#
#    media_gap_meta_2024_pp  pct_municipios_atingiram_meta_2024  \
# 0                     NaN                                 NaN
# 1                2.218913                           55.434783
# ...

# %%
data_gold_resumo_municipal_por_uf.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   sigla_uf                            26 non-null     str
#  1   municipios_na_amostra               27 non-null     int64
#  2   media_pct_alfabetizados_2023        24 non-null     float64
#  3   media_pct_alfabetizados_2024        25 non-null     float64
#  4   media_variacao_2023_2024_pp         24 non-null     float64
#  5   media_gap_meta_2024_pp              24 non-null     float64
#  6   pct_municipios_atingiram_meta_2024  24 non-null     float64
#  7   media_participacao                  25 non-null     float64
# dtypes: float64(6), int64(1), str(1)
# memory usage: 1.8 KB
